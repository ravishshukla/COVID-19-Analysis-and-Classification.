# %% [markdown]
# # Welcome to Covid19 Data Analysis Project!!!
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ### Importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Datasets" folder.

# %%
corona_dataset_csv = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
original_confirmed = corona_dataset_csv
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: We do not need the latitudes and longitudes so lets delete these columns.

# %%
df = corona_dataset_csv.drop(["Lat","Long"],axis=1)

# %%
df.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# ### The Aggregated rows by the key Country/Region need to be calculated so that country specific analysis can be done.

# %%
df_aggregated = df.groupby("Country/Region").sum()

# %%
df_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
df_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Let us now Visualize and Analyize the data of China.
# Visualization always helps for better understanding of our data, The data proves our inate assuption of china to have soring number of cases due to the origin in Wuhan, a provice in China, but the Data Speaks otherwise when compared to other major cities.

# %%
df_aggregated.loc["China"].plot()
df_aggregated.loc["Italy"].plot()
df_aggregated.loc["Spain"].plot()
plt.legend()

# %% [markdown]
# ### We need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
df_aggregated.loc['China'].plot()

# %% [markdown]
# ### Let us see the trend for the first 3 Days.

# %%
df_aggregated.loc["China"][:3].plot()

# %% [markdown]
# ### By Caculating the first derivative of the curve we can determine the rate at which the infection spread all over China in a day.

# %%
df_aggregated.loc["China"].diff().plot()

# %% [markdown]
# ### In the recorded time the Maxmimum infection rate for China comes out to be.

# %%
df_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %% [markdown]
# ### Lets do the similar Analysis for the other Two countries.

# %%
df_aggregated.loc["Italy"].diff().plot()
df_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
df_aggregated.loc["Spain"].diff().plot()
df_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### Let us carry this analysis and find the Maximum infection rate for all of the countries and add it to our Data frame.

# %%
countries = list(df_aggregated.index)
max_infection_rate = []
for c in countries :
    max_infection_rate.append(df_aggregated.loc[c].diff().max())
df_aggregated["max_infection_rate"] = max_infection_rate

# %%
df_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# ### Let us extract this column to create a new dataframe with only the max_infection_rate.

# %%
df_new = pd.DataFrame(df_aggregated["max_infection_rate"])

# %%
df_new.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# ### We now start our Intuitive analysis of COVID-19, For this we shall:
# ##### - Importing the WorldHappinessReport.csv dataset
# ##### - selecting needed columns for our analysis
# ##### - join the datasets
# ##### - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Importing the dataset

# %%
happiness_report = pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Lets Process and Clean the Data.

# %%
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
df_happy = happiness_report.drop(useless_cols, axis=1)
df_happy.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### We make Country as the Key to ease our operations.

# %%
df_happy.set_index("Country or region", inplace=True)
df_happy.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### Now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
df_new.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
df_new.shape
# Out:
# (187, 1)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
df_happy.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
df_happy.shape
# Out:
# (156, 4)

# %%
data = df_new.join(df_happy,how="inner") #inner joint because no. of countries in corona dataset was more than the happiness dataset
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Creating the Correlation matrix.

# %%
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %% [markdown]
# ### Lets Visualization of the results.
# We visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Plotting GDP per capita vs maximum Infection rate.

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x,np.log(y))

# %% [markdown]
# ## We use Linear Regression in this Scatter plot to find the Best-Fit-Line for the given Dstribution.

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Plotting Social support vs maximum Infection rate.

# %%
sns.scatterplot(data["Social support"],np.log(y))

# %% [markdown]
# ## Applying Regression Again.

# %%
sns.regplot(data["Social support"], np.log(y))

# %% [markdown]
# # Detecting COVID-19 with Chest X Ray using PyTorch
#
# Image classification of Chest X Rays in one of three classes: Normal, Viral Pneumonia, COVID-19
#
# Dataset from [COVID-19 Radiography Dataset](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database) on Kaggle

# %% [markdown]
# # Importing Libraries

# %%
# %matplotlib inline

import os
import shutil
import random
import torch
import torchvision
import numpy as np

from PIL import Image
from matplotlib import pyplot as plt

torch.manual_seed(0)

print('Using PyTorch version', torch.__version__)
print("Imported!!!")
# Out:
# Imported!!!

# %% [markdown]
# # Preparing Training and Test Sets

# %%
class_names = ['normal', 'viral', 'covid']
root_dir = 'COVID-19 Radiography Database'
source_dirs = ['NORMAL', 'Viral Pneumonia', 'COVID-19']

if os.path.isdir(os.path.join(root_dir, source_dirs[1])):
    os.mkdir(os.path.join(root_dir, 'test'))

    for i, d in enumerate(source_dirs):
        os.rename(os.path.join(root_dir, d), os.path.join(root_dir, class_names[i]))

    for c in class_names:
        os.mkdir(os.path.join(root_dir, 'test', c))

    for c in class_names:
        images = [x for x in os.listdir(os.path.join(root_dir, c)) if x.lower().endswith('png')]
        selected_images = random.sample(images, 30)
        for image in selected_images:
            source_path = os.path.join(root_dir, c, image)
            target_path = os.path.join(root_dir, 'test', c, image)
            shutil.move(source_path, target_path)
print("Improted!!!")
# Out:
# Imported!!!

# %% [markdown]
# # Creating Custom Dataset

# %%
class ChestXRayDataset(torch.utils.data.Dataset): #Subclass from pytorch
    def __init__(self, image_dirs, transform): #Initializer fuction
        def get_images(class_name):
            images = [x for x in os.listdir(image_dirs[class_name]) if x.lower().endswith('png')]
            print(f'Found {len(images)} {class_name} examples')
            return images
        
        self.images = {}
        self.class_names = ['normal','viral','covid']
        
        for c in self.class_names:
            self.images[c] = get_images(c)
        
        self.image_dirs = image_dirs
        self.transform = transform
            
            
    def __len__(self):
        return sum([len(self.images[c]) for c in self.class_names])
    
    
    def __getitem__(self, index):
        class_name = random.choice(self.class_names)
        index = index % len(self.images[class_name]) # this is done because covid dataset has lesser no. of examples from normal and viral, so if an index comes to be 1300 it will be stisfied by the normal or viral by not by covid, so we take the remainder of the index when divided index when divided by the length of the images in that class
        image_name = self.images[class_name][index]
        image_path = os.path.join(self.image_dirs[class_name], image_name)
        image = Image.open(image_path).convert('RGB') #Image belongs to Pillow module(PIL) #we have to specify RGB because we are going to use Resnet18's pretrained weights wihch are trained from the "ImageNet" dataset
        return self.transform(image),self.class_names.index(class_name)

# %% [markdown]
# # Image Transformations

# %%
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(size=(224,224)), #covert to a size that our model recognizes
    torchvision.transforms.RandomHorizontalFlip(), #Data augmentation
    torchvision.transforms.ToTensor(), # Because pytorch dos not recognize pIL images, it recognizes Tensors
    torchvision.transforms.Normalize(mean = [0.485, 0.456, 0.406], #we normalize ot to specific range for the 3 Channels(RGB) which was used when Resnet18 model was trained on ImageNet Data set to benifit from the Transfer Learning
                                    std = [0.229,0.224,0.225])

])

# %%
test_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(size=(224,224)), #covert to a size that our model recogniz
    torchvision.transforms.ToTensor(), # Because pytorch dos not recognize pIL images, it recognizes Tensors
    torchvision.transforms.Normalize(mean = [0.485, 0.456, 0.406], #we normalize ot to specific range for the 3 Channels(RGB) which was used when Resnet18 model was trained on ImageNet Data set to benifit from the Transfer Learning
                                    std = [0.229,0.224,0.225])

])

# %% [markdown]
# # Prepare DataLoader

# %%
train_dirs = {
    'normal': 'COVID-19 Radiography Database/normal',
    'viral': 'COVID-19 Radiography Database/viral',
    'covid': 'COVID-19 Radiography Database/covid'
}

train_dataset = ChestXRayDataset(train_dirs, train_transform)
# Out:
# Found 1311 normal examples
# Found 1315 viral examples
# Found 189 covid examples

# %%
test_dirs = {
    'normal': 'COVID-19 Radiography Database/test/normal',
    'viral': 'COVID-19 Radiography Database/test/viral',
    'covid': 'COVID-19 Radiography Database/test/covid'
}

test_dataset = ChestXRayDataset(test_dirs, test_transform)
# Out:
# Found 30 normal examples
# Found 30 viral examples
# Found 30 covid examples

# %%
batch_size = 6

dl_train = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size,
                                      shuffle=True)
dl_test = torch.utils.data.DataLoader(test_dataset, batch_size= batch_size, shuffle=True)


print("Number of traing batches ", len(dl_train))
print("Number of Test Batches ", len(dl_test))
# Out:
# Number of traing batches  470
# Number of Test Batches  15

# %% [markdown]
# # Data Visualization

# %%
class_names = train_dataset.class_names


def show_images(images,lables,preds):
    plt.figure(figsize=(8,4))
    
    for i, image in enumerate(images):
        plt.subplot(1,6, i + 1, xticks=[],yticks=[])
        image = image.numpy().transpose((1, 2, 0)) # transpose in such a way that the first axis is the last becaus  the pytorch implimentation is channel first then height then the width
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229,0.224,0.225])
        image = image *std +mean #convert imgae pixel value to the state before normalization
        image = np.clip(image, 0., 1.)
        plt.imshow(image)
        
        col = 'green' if preds[i] == labels[i] else 'red'
        
        plt.xlabel(f'{class_names[int(labels[i].numpy())]}')
        plt.ylabel(f'{class_names[int(preds[i].numpy())]}', color = col)
        
    plt.tight_layout()
    plt.show()

# %%
images,labels = next(iter(dl_train))
show_images(images, labels, labels)

# %%
images, labels = next(iter(dl_test))
show_images(images, labels, labels)

# %% [markdown]
# # Creating the Model

# %%
resnet18 = torchvision.models.resnet18(pretrained=True)
print(resnet18)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
resnet18.fc = torch.nn.Linear(in_features=512,out_features=3)
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(resnet18.parameters(), lr = 3e-5) # Adam works of stochastic grad descent, and lr is the learning rate

# %%
def show_preds():
    resnet18.eval()
    images, labels = next(iter(dl_test))
    outputs = resnet18(images)
    _, preds = torch.max(outputs, 1)#torch.max( returns values and the index for all the outputs, we dont want the value just the index so we use, (_, preds) syntax
    show_images(images,labels,preds)

# %%
show_preds()

# %% [markdown]
# # Training the Model

# %%
def train(epochs):
    print('Strating traing...')
    for e in range(0, epochs):
        print('='*20)
        print(f'Starting epoch {e+1}/{epochs}')
        print('='*20)
        
        train_loss =0
        
        resnet18.train()
        
        for train_step, (images, labels) in enumerate(dl_train):
            optimizer.zero_grad()
            outputs = resnet18(images)
            loss = loss_fn(outputs, labels)
            loss.backward() #this is the back propagation step
            optimizer.step()
            train_loss += loss.item()
            if train_step %20 ==0:
                print('Eavaluating Modelat step', train_step)
                acc = 0
                val_loss = 0
                resnet18.eval()
                
                for val_step, (images, labels) in enumerate(dl_test):
                    outputs = resnet18(images)
                    loss = loss_fn(outputs, labels)
                    val_loss += loss.item()
                            
                    _, preds = torch.max(outputs, 1) #Dimension 1 corresponds to the values and 2 corresponds to the examples
                    acc += sum((preds == labels).numpy())
                val_loss /= (val_step +1)
                acc = acc/ len(test_dataset)
                print(f'Val loss; {val_loss:.4f}, Acc: {acc:.4f}')
                show_preds()
                
                resnet18.train()
                
                if acc> 0.95:
                    print('Performance condition Satisfied...')
                    return
                
        train_loss /= (train_step + 1)
        print(f'Training loss : {train_loss: .4f}')

# %%
train(epochs=2)
# Out:
# Strating traing...
# ...
# Starting epoch 1/2
# ...
# Eavaluating Modelat step 0
# Val loss; 1.5682, Acc: 0.3444
# Eavaluating Modelat step 20
# Val loss; 0.6662, Acc: 0.8333
# Eavaluating Modelat step 40
# Val loss; 0.2448, Acc: 0.9444
# Eavaluating Modelat step 60
# Val loss; 0.2290, Acc: 0.9222
# Eavaluating Modelat step 80
# Val loss; 0.1378, Acc: 0.9444
# Eavaluating Modelat step 100
# Val loss; 0.1350, Acc: 0.9444
# Eavaluating Modelat step 120
# Val loss; 0.1135, Acc: 0.9667
# Performance condition Satisfied...

# %% [markdown]
# # Final Results

# %%
show_preds()
